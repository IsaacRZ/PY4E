# %%
import types
def hola_mundo_sin_nombre():
    print('Hola Mundo soy','WhoamI?')

def hola_mundo(name):
    return('Hola Mundo soy',name)

print(type('str'))
print(type(print()))
#print(type())
print(type(hola_mundo('Juan')))
print(type(hola_mundo_sin_nombre()))
print(type(hola_mundo))
print(type(hola_mundo_sin_nombre))

# Coincida el tipo de dato 
print(type(hola_mundo) == types.FunctionType)


#print(type())
# Out:
# <class 'str'>
#
# <class 'NoneType'>
# <class 'tuple'>
# Hola Mundo soy WhoamI?
# <class 'NoneType'>
# <class 'function'>
# <class 'function'>
# True
